# %% [markdown]
# **This notebook is an exercise in the [SQL](https://www.kaggle.com/learn/intro-to-sql) course.  You can reference the tutorial at [this link](https://www.kaggle.com/dansbecker/getting-started-with-sql-and-bigquery).**
#
# ---

# %% [markdown]
# # Introduction
#
# The first test of your new data exploration skills uses data describing crime in the city of Chicago.
#
# Before you get started, run the following cell. It sets up the automated feedback system to review your answers.

# %% [markdown]
# Use the next code cell to fetch the dataset.

# %%
from google.cloud import bigquery

# Create a "Client" object
client = bigquery.Client()

# Construct a reference to the "chicago_crime" dataset
dataset_ref = client.dataset("chicago_crime", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# %% [markdown]
# # Exercises
#
# ### 1) Count tables in the dataset
#
# How many tables are in the Chicago Crime dataset?

# %%
# List tables in the dataset
tables = list(client.list_tables(dataset_ref))

# Print the table names and count
table_names = [table.table_id for table in tables]
num_tables = len(tables)

print(f"Tables in the 'chicago_crime' dataset: {table_names}")
print(f"Total number of tables: {num_tables}")
# Out:
# Tables in the 'chicago_crime' dataset: ['crime']
# Total number of tables: 1

# %%
# Use SQL to list tables in the dataset
query = """
    SELECT table_name
    FROM `bigquery-public-data`.INFORMATION_SCHEMA.TABLES
    WHERE table_schema = 'chicago_crime'
"""

# Run the query
query_job = client.query(query, project="bigquery-public-data")
tables = query_job.result()

# Extract and print the table names
table_names = [table["table_name"] for table in tables]
num_tables = len(table_names)

print(f"Tables in the 'chicago_crime' dataset: {table_names}")
print(f"Total number of tables: {num_tables}")
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In[3], line 9
#       2 query = """
#       3     SELECT table_name
#       4     FROM `bigquery-public-data`.INFORMATION_SCHEMA.TABLES
#       5     WHERE table_schema = 'chicago_crime'
#       6 """
#       8 # Run the query
# ----> 9 query_job = client.query(query, project="bigquery-public-data")
#      10 tables = query_job.result()
#      12 # Extract and print the table names
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\cloud\bigquery\client.py:3387, in Client.query(self, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry, api_method)
#    3376     return _job_helpers.query_jobs_query(
#    3377         self,
#    3378         query,
#    (...)
#    3384         job_retry,
#    3385     )
#    3386 elif api_method == enums.QueryApiMethod.INSERT:
# -> 3387     return _job_helpers.query_jobs_insert(
#    3388         self,
#    3389         query,
#    3390         job_config,
#    3391         job_id,
#    3392         job_id_prefix,
#    3393         location,
#    3394         project,
#    3395         retry,
#    3396         timeout,
#    3397         job_retry,
#    3398     )
#    3399 else:
#    3400     raise ValueError(f"Got unexpected value for api_method: {repr(api_method)}")
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\cloud\bigquery\_job_helpers.py:158, in query_jobs_insert(client, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry)
#     155     else:
#     156         return query_job
# --> 158 future = do_query()
#     159 # The future might be in a failed state now, but if it's
#     160 # unrecoverable, we'll find out when we ask for it's result, at which
#     161 # point, we may retry.
#     162 if not job_id_given:
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\cloud\bigquery\_job_helpers.py:135, in query_jobs_insert.<locals>.do_query()
#     132 query_job = job.QueryJob(job_ref, query, client=client, job_config=job_config)
#     134 try:
# --> 135     query_job._begin(retry=retry, timeout=timeout)
#     136 except core_exceptions.Conflict as create_exc:
#     137     # The thought is if someone is providing their own job IDs and they get
#     138     # their job ID generation wrong, this could end up returning results for
#     139     # the wrong query. We thus only try to recover if job ID was not given.
#     140     if job_id_given:
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\cloud\bigquery\job\query.py:1379, in QueryJob._begin(self, client, retry, timeout)
#    1359 """API call:  begin the job via a POST request
#    1360
#    1361 See
#    (...)
#    1375     ValueError: If the job has already begun.
#    1376 """
#    1378 try:
# -> 1379     super(QueryJob, self)._begin(client=client, retry=retry, timeout=timeout)
#    1380 except exceptions.GoogleAPICallError as exc:
#    1381     exc.message = _EXCEPTION_FOOTER_TEMPLATE.format(
#    1382         message=exc.message, location=self.location, job_id=self.job_id
#    1383     )
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\cloud\bigquery\job\base.py:723, in _AsyncJob._begin(self, client, retry, timeout)
#     720 # jobs.insert is idempotent because we ensure that every new
#     721 # job has an ID.
#     722 span_attributes = {"path": path}
# --> 723 api_response = client._call_api(
#     724     retry,
#     725     span_name="BigQuery.job.begin",
#     726     span_attributes=span_attributes,
#     727     job_ref=self,
#     728     method="POST",
#     729     path=path,
#     730     data=self.to_api_repr(),
#     731     timeout=timeout,
#     732 )
#     733 self._set_properties(api_response)
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\cloud\bigquery\client.py:818, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     814 if span_name is not None:
#     815     with create_span(
#     816         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     817     ):
# --> 818         return call()
#     820 return call()
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\api_core\retry.py:372, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     368 target = functools.partial(func, *args, **kwargs)
#     369 sleep_generator = exponential_sleep_generator(
#     370     self._initial, self._maximum, multiplier=self._multiplier
#     371 )
# --> 372 return retry_target(
#     373     target,
#     374     self._predicate,
#     375     sleep_generator,
#     376     self._timeout,
#     377     on_error=on_error,
#     378 )
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\api_core\retry.py:207, in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     205 for sleep in sleep_generator:
#     206     try:
# --> 207         result = target()
#     208         if inspect.isawaitable(result):
#     209             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\cloud\_http\__init__.py:494, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#    (...)
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
# --> 494     raise exceptions.from_http_response(response)
#     496 if expect_json and response.content:
#     497     return response.json()
#
# Forbidden: 403 POST https://bigquery.googleapis.com/bigquery/v2/projects/bigquery-public-data/jobs?prettyPrint=false: Access Denied: Project bigquery-public-data: User does not have bigquery.jobs.create permission in project bigquery-public-data.
#
# Location: None
# Job ID: 38776199-449f-47b1-b325-eeacf12c19db

# %% [markdown]
# ### 2) Explore the table schema
#
# How many columns in the `crime` table have `TIMESTAMP` data?

# %%
# Use SQL to count columns with TIMESTAMP data in the crime table
query = """
    SELECT COUNT(column_name) as num_timestamp_fields
    FROM `bigquery-public-data`.INFORMATION_SCHEMA.COLUMNS
    WHERE table_name = 'crime' AND data_type = 'TIMESTAMP'
"""

# Run the query
query_job = client.query(query, project="bigquery-public-data")
result = query_job.result()

# Extract and print the number of columns with TIMESTAMP data
for row in result:
    num_timestamp_fields = row["num_timestamp_fields"]

print(f"Number of columns with TIMESTAMP data in the 'crime' table: {num_timestamp_fields}")
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In[7], line 9
#       2 query = """
#       3     SELECT COUNT(column_name) as num_timestamp_fields
#       4     FROM `bigquery-public-data`.INFORMATION_SCHEMA.COLUMNS
#       5     WHERE table_name = 'crime' AND data_type = 'TIMESTAMP'
#       6 """
#       8 # Run the query
# ----> 9 query_job = client.query(query, project="bigquery-public-data")
#      10 result = query_job.result()
#      12 # Extract and print the number of columns with TIMESTAMP data
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\cloud\bigquery\client.py:3387, in Client.query(self, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry, api_method)
#    3376     return _job_helpers.query_jobs_query(
#    3377         self,
#    3378         query,
#    (...)
#    3384         job_retry,
#    3385     )
#    3386 elif api_method == enums.QueryApiMethod.INSERT:
# -> 3387     return _job_helpers.query_jobs_insert(
#    3388         self,
#    3389         query,
#    3390         job_config,
#    3391         job_id,
#    3392         job_id_prefix,
#    3393         location,
#    3394         project,
#    3395         retry,
#    3396         timeout,
#    3397         job_retry,
#    3398     )
#    3399 else:
#    3400     raise ValueError(f"Got unexpected value for api_method: {repr(api_method)}")
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\cloud\bigquery\_job_helpers.py:158, in query_jobs_insert(client, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry)
#     155     else:
#     156         return query_job
# --> 158 future = do_query()
#     159 # The future might be in a failed state now, but if it's
#     160 # unrecoverable, we'll find out when we ask for it's result, at which
#     161 # point, we may retry.
#     162 if not job_id_given:
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\cloud\bigquery\_job_helpers.py:135, in query_jobs_insert.<locals>.do_query()
#     132 query_job = job.QueryJob(job_ref, query, client=client, job_config=job_config)
#     134 try:
# --> 135     query_job._begin(retry=retry, timeout=timeout)
#     136 except core_exceptions.Conflict as create_exc:
#     137     # The thought is if someone is providing their own job IDs and they get
#     138     # their job ID generation wrong, this could end up returning results for
#     139     # the wrong query. We thus only try to recover if job ID was not given.
#     140     if job_id_given:
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\cloud\bigquery\job\query.py:1379, in QueryJob._begin(self, client, retry, timeout)
#    1359 """API call:  begin the job via a POST request
#    1360
#    1361 See
#    (...)
#    1375     ValueError: If the job has already begun.
#    1376 """
#    1378 try:
# -> 1379     super(QueryJob, self)._begin(client=client, retry=retry, timeout=timeout)
#    1380 except exceptions.GoogleAPICallError as exc:
#    1381     exc.message = _EXCEPTION_FOOTER_TEMPLATE.format(
#    1382         message=exc.message, location=self.location, job_id=self.job_id
#    1383     )
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\cloud\bigquery\job\base.py:723, in _AsyncJob._begin(self, client, retry, timeout)
#     720 # jobs.insert is idempotent because we ensure that every new
#     721 # job has an ID.
#     722 span_attributes = {"path": path}
# --> 723 api_response = client._call_api(
#     724     retry,
#     725     span_name="BigQuery.job.begin",
#     726     span_attributes=span_attributes,
#     727     job_ref=self,
#     728     method="POST",
#     729     path=path,
#     730     data=self.to_api_repr(),
#     731     timeout=timeout,
#     732 )
#     733 self._set_properties(api_response)
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\cloud\bigquery\client.py:818, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     814 if span_name is not None:
#     815     with create_span(
#     816         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     817     ):
# --> 818         return call()
#     820 return call()
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\api_core\retry.py:372, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     368 target = functools.partial(func, *args, **kwargs)
#     369 sleep_generator = exponential_sleep_generator(
#     370     self._initial, self._maximum, multiplier=self._multiplier
#     371 )
# --> 372 return retry_target(
#     373     target,
#     374     self._predicate,
#     375     sleep_generator,
#     376     self._timeout,
#     377     on_error=on_error,
#     378 )
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\api_core\retry.py:207, in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     205 for sleep in sleep_generator:
#     206     try:
# --> 207         result = target()
#     208         if inspect.isawaitable(result):
#     209             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File c:\Users\aga\anaconda3\Lib\site-packages\google\cloud\_http\__init__.py:494, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#    (...)
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
# --> 494     raise exceptions.from_http_response(response)
#     496 if expect_json and response.content:
#     497     return response.json()
#
# Forbidden: 403 POST https://bigquery.googleapis.com/bigquery/v2/projects/bigquery-public-data/jobs?prettyPrint=false: Access Denied: Project bigquery-public-data: User does not have bigquery.jobs.create permission in project bigquery-public-data.
#
# Location: None
# Job ID: f2393609-f390-41d9-b566-f1441083f789

# %% [markdown]
# ### 3) Create a crime map
#
# If you wanted to create a map with a dot at the location of each crime, what are the names of the two fields you likely need to pull out of the `crime` table to plot the crimes on a map?

# %%
fields_for_plotting = ['latitude', 'longitude']

# %% [markdown]
# Thinking about the question above, there are a few columns that appear to have geographic data. Look at a few values (with the `list_rows()` command) to see if you can determine their relationship.  Two columns will still be hard to interpret. But it should be obvious how the `location` column relates to `latitude` and `longitude`.

# %%
# Specify the table name (replace with the actual table name if different)
table_name = "crime"

# Construct a reference to the crime table
table_ref = dataset_ref.table(table_name)

# Get the schema of the crime table
table = client.get_table(table_ref)

# Use list_rows to inspect a few values
rows = client.list_rows(table, max_results=5)  # Adjust max_results as needed

# Display the selected columns for each row
for row in rows:
    print(f"Location: {row['location']}")
    print(f"Latitude: {row['latitude']}")
    print(f"Longitude: {row['longitude']}")
    print("------")
# Out:
# Location: (41.885729338, -87.625780935)
# Latitude: 41.885729338
# Longitude: -87.625780935
# ------
# Location: (41.885112119, -87.624484053)
# Latitude: 41.885112119
# Longitude: -87.624484053
# ------
# Location: (41.885191719, -87.624486846)
# Latitude: 41.885191719
# Longitude: -87.624486846
# ------
# Location: (41.884484216, -87.629030004)
# Latitude: 41.884484216
# Longitude: -87.629030004
# ------
# Location: (41.885729587, -87.625821329)
# Latitude: 41.885729587
# Longitude: -87.625821329
# ------

# %% [markdown]
# # Keep going
#
# You've looked at the schema, but you haven't yet done anything exciting with the data itself. Things get more interesting when you get to the data, so keep going to **[write your first SQL query](https://www.kaggle.com/dansbecker/select-from-where).**

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-sql/discussion) to chat with other learners.*
